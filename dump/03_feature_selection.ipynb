# %% [markdown]
# # Feature Selection Notebook
#
# ## Introduction
# There is a very high amount of features in data. Depending on the clustering strategy this can lead to the Curse of Dimensionaliy in a clustering scenario. Refer to [this answer on Stack Exchange](https://stats.stackexchange.com/questions/232500/how-do-i-know-my-k-means-clustering-algorithm-is-suffering-from-the-curse-of-dim) for a more in-depth discussion about it.
#
# ## Methodology
# A way to select features aiming towards reducing dimensionality is to use the information in the customers data that is not present in the general dataset (i.e. `CUSTOMER_GROUP, ONLINE_PURCHASE AND PRODUCT_GROUP` columns) to choose the columns that help the most in segmenting these columns. This way, we can choose the features that most likely segment customers and can use them to understand the behaviour of the general population and the customer population.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest, mutual_info_classif
import pickle

# %%
df_customers = pd.read_parquet('data/refined/customers_data.parquet')

# %% [markdown]
# # Checking for multicolinearity
#
# We should check especially for multicolinearity for categorical variables (ordinals are categorical nontheless), since there are so many of them.
# In this context, too many variables can lead to the Curse of Dimensionality so that it is hard to set entries apart in the feature space.
#
# To compare approx. 300 variables with themselves would generate a result too expensive computationally (approx. 44850 unique combinations), since we have to evaluate all variables against themselves.
# As a proxy, we will use the information-levels to calculate the colinearities within each level to keep only the most important features for each level.

# %% [markdown]
# ## Calculating Multicolinearities by Information Group

# %%
# We wont use numeric vars to calculate Cramer's V

numeric_vars = ['ANZ_HAUSHALTE_AKTIV',
                'ANZ_HH_TITEL',
                'ANZ_PERSONEN',
                'ANZ_TITEL',
                'GEBURTSJAHR',
                'KBA13_ANZAHL_PKW',
                'MIN_GEBAEUDEJAHR']

# %%
num_var_filter = ~col_classification['Attribute'].isin(numeric_vars)

# %%
def calculate_cramers_v(arr1, arr2):

    '''
    Calculates Cramer's V for two arrays.
    The value lies between 0 and 1 (inclusive)

    :param arr1: Array of categorical variable
    :param arr2: Array of categorical variable

    :return v: Cramer's V index value
    '''

    crosstab = stats.contingency.crosstab(arr1, arr2)[1]

    chi2 = stats.chi2_contingency(crosstab)[0]

    # calculating the total number of observations
    n = np.sum(crosstab)

    # getting the degrees of freedom
    dof = min(crosstab.shape)-1
    
    # calculating cramer's v
    v = np.sqrt(chi2/(n*dof))

    return v

def calculate_frame_cramer_coefs(dataframe):

    '''
    Calculates pairwise Cramer's V for all possible combinations of categorical variables in 'dataframe'.
    Similar behaviour to pandas' .corr() method.

    :param dataframe: Pandas DataFrame columns with categorical variables

    :return matrix: Pairwise matrix with all variable combinations
    '''
    
    numpy_frame = dataframe.dropna().values

    matrix = np.diag([1.0] * numpy_frame.shape[1])

    table_range = list(range(0,numpy_frame.shape[1]))

    # Getting unique index combinations to minimize iterations
    combos = [combo for combo in itertools.combinations(table_range,2)]

    for i, j in combos:
        
        v = calculate_cramers_v(numpy_frame[:,i], numpy_frame[:,j])

        matrix[i,j] = v

        matrix[j,i] = v

    return matrix

# %% [markdown]
# **WARNING: Running the cells below can take a while. That is why the values are exported to csv, so we can use them later without going through these calculations**

# %%
# # Sorting information levels by amount of columns to generate results faster
# sorted_col_classes = col_classification['Information level'].value_counts(ascending=True)

# %%
# for i, c in enumerate(sorted_col_classes.index): : #  enumerate(['125m x 125m Grid','Household'])

#     relevant_cols = col_classification[(col_classification['Information level'] == c) & num_var_filter]['Attribute']

#     v_matrix = calculate_frame_cramer_coefs(census[relevant_cols])

#     v_frame = pd.DataFrame(v_matrix, columns = relevant_cols, index = relevant_cols)

#     v_frame.name = c

#     v_frame.to_csv(f'data/trusted/{v_frame.name}_cramer.csv', sep = ';')

#     if i == 0:

#         v_frame_list = [v_frame]

#     else:

#         v_frame_list.append(v_frame)

# %% [markdown]
# ---

# %%
DATA_PATH = 'data/trusted/'

# %%
cramer_frame_list = []

for file in os.listdir(DATA_PATH):

    # Skipping to use updated version
    if file == 'Microcell (RR3_ID)_cramer.csv':

        continue

    if file.endswith('_cramer.csv'):

        name = file.replace('_cramer.csv','')

        frame = pd.read_csv(os.path.join(DATA_PATH, file), sep = ';', index_col = 0)

        if file == 'Microcell (RR3_ID)_updated_cramer.csv':

            frame = pd.read_csv(os.path.join(DATA_PATH, file), index_col = 0)

        frame.name = name
    
        cramer_frame_list.append(frame)

# %% [markdown]
# # Feature Selection
# Based on multicolinearity and business definitions of columns within each group

# %% [markdown]
# ## 125m x 125m Grid
# For this information level, what does not relate to banking activities or marginally related to the clients' business (mail-order organics) will be drop and not analyzed.

# %%
# Keeping columns related to banking activities and related to clients' businesses
grid_cols_list = ['D19_BANKEN_DIREKT',
                            'D19_BANKEN_GROSS',
                            'D19_BANKEN_LOKAL',
                            'D19_BANKEN_REST',
                            'D19_BIO_OEKO',
                            'D19_DIGIT_SERV',
                            'D19_LEBENSMITTEL',
                            'D19_VOLLSORTIMENT',
                            'D19_VERSAND_REST']

# %%
cramer_frame_list[0].columns
# Out:
# Index(['D19_BANKEN_DIREKT', 'D19_BANKEN_GROSS', 'D19_BANKEN_LOKAL',
#        'D19_BANKEN_REST', 'D19_BEKLEIDUNG_GEH', 'D19_BEKLEIDUNG_REST',
#        'D19_BIO_OEKO', 'D19_BILDUNG', 'D19_DIGIT_SERV', 'D19_DROGERIEARTIKEL',
#        'D19_ENERGIE', 'D19_FREIZEIT', 'D19_GARTEN', 'D19_HANDWERK',
#        'D19_HAUS_DEKO', 'D19_KINDERARTIKEL', 'D19_KOSMETIK',
#        'D19_LEBENSMITTEL', 'D19_NAHRUNGSERGAENZUNG', 'D19_RATGEBER',
#        'D19_REISEN', 'D19_SAMMELARTIKEL', 'D19_SCHUHE', 'D19_SONSTIGE',
#        'D19_TECHNIK', 'D19_TELKO_MOBILE', 'D19_TELKO_REST', 'D19_TIERARTIKEL',
#        'D19_VERSICHERUNGEN', 'D19_VOLLSORTIMENT', 'D19_VERSAND_REST',
#        'D19_WEIN_FEINKOST', 'D19_BUCH_CD', 'D19_LETZTER_KAUF_BRANCHE',
#        'D19_LOTTO', 'D19_SOZIALES'],
#       dtype='object')

# %%
cramer_frame_list[0].loc[grid_cols_list, grid_cols_list].style.background_gradient()
# Out:
# <style type="text/css">
# #T_7696c_row0_col0, #T_7696c_row1_col1, #T_7696c_row2_col2, #T_7696c_row3_col3, #T_7696c_row4_col4, #T_7696c_row5_col5, #T_7696c_row6_col6, #T_7696c_row7_col7, #T_7696c_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7696c_row0_col1 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_7696c_row0_col2, #T_7696c_row3_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_7696c_row0_col3 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_7696c_row0_col4, #T_7696c_row3_col0, #T_7696c_row6_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_7696c_row0_col5, #T_7696c_row6_col8, #T_7696c_row7_col4, #T_7696c_row7_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_7696c_row0_col6, #T_7696c_row1_col7 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_7696c_row0_col7, #T_7696c_row1_col8, #T_7696c_row4_col2, #T_7696c_row5_col8, #T_7696c_row7_col1, #T_7696c_row8_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_7696c_row0_col8 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_7696c_row1_col0 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_7696c_row1_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_7696c_row1_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_7696c_row1_col4, #T_7696c_row1_col6, #T_7696c_row2_col0, #T_7696c_row2_col5, #T_7696c_row2_col7, #T_7696c_row2_col8, #T_7696c_row4_col1, #T_7696c_row5_col2, #T_7696c_row5_col3, #T_7696c_row5_col6, #T_7696c_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7696c_row1_col5, #T_7696c_row2_col1, #T_7696c_row2_col3, #T_7696c_row2_col6, #T_7696c_row3_col5, #T_7696c_row6_col0, #T_7696c_row6_col5, #T_7696c_row7_col3, #T_7696c_row8_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7696c_row2_col4, #T_7696c_row4_col3, #T_7696c_row4_col5, #T_7696c_row4_col8, #T_7696c_row6_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_7696c_row3_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_7696c_row3_col4, #T_7696c_row8_col1, #T_7696c_row8_col7 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_7696c_row3_col6, #T_7696c_row3_col7, #T_7696c_row4_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_7696c_row3_col8, #T_7696c_row7_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_7696c_row4_col0, #T_7696c_row5_col4, #T_7696c_row8_col3, #T_7696c_row8_col5 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_7696c_row4_col6, #T_7696c_row8_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_7696c_row5_col0, #T_7696c_row7_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_7696c_row5_col1, #T_7696c_row6_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_7696c_row5_col7, #T_7696c_row6_col1, #T_7696c_row6_col2, #T_7696c_row7_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_7696c_row8_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# </style>
# <table id="T_7696c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7696c_level0_col0" class="col_heading level0 col0" >D19_BANKEN_DIREKT</th>
#       <th id="T_7696c_level0_col1" class="col_heading level0 col1" >D19_BANKEN_GROSS</th>
#       <th id="T_7696c_level0_col2" class="col_heading level0 col2" >D19_BANKEN_LOKAL</th>
#       <th id="T_7696c_level0_col3" class="col_heading level0 col3" >D19_BANKEN_REST</th>
#       <th id="T_7696c_level0_col4" class="col_heading level0 col4" >D19_BIO_OEKO</th>
#       <th id="T_7696c_level0_col5" class="col_heading level0 col5" >D19_DIGIT_SERV</th>
#       <th id="T_7696c_level0_col6" class="col_heading level0 col6" >D19_LEBENSMITTEL</th>
#       <th id="T_7696c_level0_col7" class="col_heading level0 col7" >D19_VOLLSORTIMENT</th>
#       <th id="T_7696c_level0_col8" class="col_heading level0 col8" >D19_VERSAND_REST</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Attribute</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7696c_level0_row0" class="row_heading level0 row0" >D19_BANKEN_DIREKT</th>
#       <td id="T_7696c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T
row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_7696c_row4_col5" class="data row4 col5" >0.078483</td>
#       <td id="T_7696c_row4_col6" class="data row4 col6" >0.117177</td>
#       <td id="T_7696c_row4_col7" class="data row4 col7" >0.055483</td>
#       <td id="T_7696c_row4_col8" class="data row4 col8" >0.099630</td>

# %% [markdown]
# Even though direct banking has some correlation to big banks, they convey different informations that might be interesting to the user.
# For instance, who uses direct banking might be a more tech-savy user. This gives us a different segment indication then simply assuming a user uses big banks.

# %% [markdown]
# ## Buildings

# %%
cramer_frame_list[1].name
# Out:
# 'Building'

# %%
cramer_frame_list[1].style.background_gradient()
# Out:
# <style type="text/css">
# #T_dc31f_row0_col0, #T_dc31f_row1_col1, #T_dc31f_row2_col2, #T_dc31f_row3_col3, #T_dc31f_row4_col4, #T_dc31f_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_dc31f_row0_col1, #T_dc31f_row0_col2, #T_dc31f_row0_col4, #T_dc31f_row0_col5, #T_dc31f_row1_col0, #T_dc31f_row2_col0, #T_dc31f_row2_col3, #T_dc31f_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_dc31f_row0_col3 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_dc31f_row1_col2, #T_dc31f_row2_col1 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_dc31f_row1_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_dc31f_row1_col4, #T_dc31f_row4_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_dc31f_row1_col5 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_dc31f_row2_col4, #T_dc31f_row4_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_dc31f_row2_col5 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_dc31f_row3_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_dc31f_row3_col1, #T_dc31f_row4_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_dc31f_row3_col2, #T_dc31f_row5_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_dc31f_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_dc31f_row3_col5, #T_dc31f_row5_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_dc31f_row4_col3, #T_dc31f_row5_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_dc31f_row5_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_dc31f_row5_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# </style>
# <table id="T_dc31f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc31f_level0_col0" class="col_heading level0 col0" >GEBAEUDETYP</th>
#       <th id="T_dc31f_level0_col1" class="col_heading level0 col1" >KBA05_HERSTTEMP</th>
#       <th id="T_dc31f_level0_col2" class="col_heading level0 col2" >KBA05_MODTEMP</th>
#       <th id="T_dc31f_level0_col3" class="col_heading level0 col3" >KONSUMNAEHE</th>
#       <th id="T_dc31f_level0_col4" class="col_heading level0 col4" >OST_WEST_KZ</th>
#       <th id="T_dc31f_level0_col5" class="col_heading level0 col5" >WOHNLAGE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Attribute</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc31f_level0_row0" class="row_heading level0 row0" >GEBAEUDETYP</th>
#       <td id="T_dc31f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dc31f_row0_col1" class="data row0 col1" >0.058127</td>
#       <td id="T_dc31f_row0_col2" class="data row0 col2" >0.057239</td>
#       <td id="T_dc31f_row0_col3" class="data row0 col3" >0.146835</td>
#       <td id="T_dc31f_row0_col4" class="data row0 col4" >0.054584</td>
#       <td id="T_dc31f_row0_col5" class="data row0 col5" >0.071675</td>
#     </tr>
#     <tr>
#       <th id="T_dc31f_level0_row1" class="row_heading level0 row1" >KBA05_HERSTTEMP</th>
#       <td id="T_dc31f_row1_col0" class="data row1 col0" >0.058127</td>
#       <td id="T_dc31f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dc31f_row1_col2" class="data row1 col2" >0.505993</td>
#       <td id="T_dc31f_row1_col3" class="data row1 col3" >0.081404</td>
#       <td id="T_dc31f_row1_col4" class="data row1 col4" >0.255567</td>
#       <td id="T_dc31f_row1_col5" class="data row1 col5" >0.303144</td>
#     </tr>
#     <tr>
#       <th id="T_dc31f_level0_row2" class="row_heading level0 row2" >KBA05_MODTEMP</th>
#       <td id="T_dc31f_row2_col0" class="data row2 col0" >0.057239</td>
#       <td id="T_dc31f_row2_col1" class="data row2 col1" >0.505993</td>
#       <td id="T_dc31f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_dc31f_row2_col3" class="data row2 col3" >0.073290</td>
#       <td id="T_dc31f_row2_col4" class="data row2 col4" >0.099981</td>
#       <td id="T_dc31f_row2_col5" class="data row2 col5" >0.298161</td>
#     </tr>
#     <tr>
#       <th id="T_dc31f_level0_row3" class="row_heading level0 row3" >KONSUMNAEHE</th>
#       <td id="T_dc31f_row3_col0" class="data row3 col0" >0.146835</td>
#       <td id="T_dc31f_row3_col1" class="data row3 col1" >0.081404</td>
#       <td id="T_dc31f_row3_col2" class="data row3 col2" >0.073290</td>
#       <td id="T_dc31f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_dc31f_row3_col4" class="data row3 col4" >0.109692</td>
#       <td id="T_dc31f_row3_col5" class="data row3 col5" >0.167219</td>
#     </tr>
#     <tr>
#       <th id="T_dc31f_level0_row4" class="row_heading level0 row4" >OST_WEST_KZ</th>
#       <td id="T_dc31f_row4_col0" class="data row4 col0" >0.054584</td>
#       <td id="T_dc31f_row4_col1" class="data row4 col1" >0.255567</td>
#       <td id="T_dc31f_row4_col2" class="data row4 col2" >0.099981</td>
#       <td id="T_dc31f_row4_col3" class="data row4 col3" >0.109692</td>
#       <td id="T_dc31f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_dc31f_row4_col5" class="data row4 col5" >0.094349</td>
#     </tr>
#     <tr>
#       <th id="T_dc31f_level0_row5" class="row_heading level0 row5" >WOHNLAGE</th>
#       <td id="T_dc31f_row5_col0" class="data row5 col0" >0.071675</td>
#       <td id="T_dc31f_row5_col1" class="data row5 col1" >0.303144</td>
#       <td id="T_dc31f_row5_col2" class="data row5 col2" >0.298161</td>
#       <td id="T_dc31f_row5_col3" class="data row5 col3" >0.167219</td>
#       <td id="T_dc31f_row5_col4" class="data row5 col4" >0.094349</td>
#       <td id="T_dc31f_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# KBA05_HERSTTEMP and KBA05_MODTEMP seem to have shared information. They are more closely related to auto-manufacturing then actually characteristics of repondents themselves. They may belong better to the RR3_ID class.
#
# Either way, it makes sanse that car brands and segments are correlated to eachother as well as living conditions in a neighbourhood (WOHNANLAGE).
#
# No other columns from the group will be dropped

# %%
buildings_col_list = list(cramer_frame_list[1].columns.drop(['KBA05_HERSTTEMP','KBA05_MODTEMP']))

# %% [markdown]
# ## RR3_ID

# %%
rr3_list = list(col_classification[(col_classification['Information level'] ==  'Microcell (RR3_ID)') & num_var_filter]['Attribute'].values) \
                + ['KBA05_HERSTTEMP','KBA05_MODTEMP']

# %%
# v_matrix = calculate_frame_cramer_coefs(census[rr3_list])

# v_frame = pd.DataFrame(v_matrix, columns = rr3_list, index = rr3_list)

# %%
# v_frame.to_csv('data/trusted/Microcell (RR3_ID)_cramer_updated.csv')

# %%
v_frame = cramer_frame_list[4]

# %%
# Checking variables that can have important multicolinearities 
((v_frame >= 0.3) & (v_frame < 1)).sum().sort_values(ascending = False).head(10)
# Out:
# KBA05_MAXHERST    9
# KBA05_MOTOR       9
# KBA05_MAXSEG      7
# KBA05_KW3         7
# KBA05_CCM1        6
# KBA05_MAXBJ       6
# KBA05_KRSKLEIN    6
# KBA05_MOD1        6
# KBA05_SEG2        5
# KBA05_MAXVORB     5
# dtype: int64

# %%
# Looking into some examples
v_frame[(v_frame >= 0.3) & (v_frame < 1)][['KBA05_MAXHERST','KBA05_MOTOR','KBA05_MAXSEG']]
# Out:
#                  KBA05_MAXHERST  KBA05_MOTOR  KBA05_MAXSEG
# KBA05_AUTOQUOT              NaN          NaN           NaN
# KBA05_BAUMAX                NaN          NaN           NaN
# KBA05_CCM1                  NaN     0.463402      0.301857
# KBA05_CCM2                  NaN     0.433955           NaN
# KBA05_CCM3                  NaN     0.401816           NaN
# KBA05_CCM4                  NaN     0.396834           NaN
# KBA05_DIESEL                NaN          NaN           NaN
# KBA05_FRAU                  NaN          NaN           NaN
# KBA05_GBZ                   NaN          NaN           NaN
# KBA05_HERST1           0.403921          NaN           NaN
# KBA05_HERST2           0.383307          NaN           NaN
# KBA05_HERST3           0.389107          NaN           NaN
# KBA05_HERST4           0.387647          NaN           NaN
# KBA05_HERST5           0.380793          NaN           NaN
# KBA05_KRSAQUOT              NaN          NaN           NaN
# KBA05_KRSHERST1        0.346650          NaN           NaN
# KBA05_KRSHERST2        0.341114          NaN           NaN
# KBA05_KRSHERST3        0.357052          NaN           NaN
# KBA05_KRSKLEIN              NaN     0.309265      0.475631
# KBA05_KRSOBER               NaN          NaN           NaN
# KBA05_KRSVAN                NaN          NaN           NaN
# KBA05_KRSZUL                NaN          NaN           NaN
# KBA05_KW1                   NaN     0.409637           NaN
# KBA05_KW2                   NaN     0.322191           NaN
# KBA05_KW3                   NaN     0.461112           NaN
# KBA05_MAXAH                 NaN          NaN           NaN
# KBA05_MAXBJ                 NaN          NaN           NaN
# KBA05_MAXHERST              NaN          NaN           NaN
# KBA05_MAXSEG                NaN     0.315032           NaN
# KBA05_MAXVORB               NaN          NaN           NaN
# KBA05_MOD1                  NaN          NaN           NaN
# KBA05_MOD2                  NaN          NaN           NaN
# KBA05_MOD3                  NaN          NaN           NaN
# KBA05_MOD4                  NaN          NaN           NaN
# KBA05_MOD8                  NaN          NaN           NaN
# KBA05_MOTOR                 NaN          NaN      0.315032
# KBA05_MOTRAD                NaN          NaN           NaN
# KBA05_SEG1                  NaN          NaN           NaN
# KBA05_SEG2                  NaN          NaN      0.420395
# KBA05_SEG3                  NaN          NaN      0.417465
# KBA05_SEG4                  NaN          NaN      0.421667
# KBA05_SEG5                  NaN          NaN           NaN
# KBA05_SEG6                  NaN          NaN           NaN
# KBA05_SEG7                  NaN          NaN           NaN
# KBA05_SEG8                  NaN          NaN           NaN
# KBA05_SEG9                  NaN          NaN           NaN
# KBA05_SEG10                 NaN          NaN           NaN
# KBA05_VORB0                 NaN          NaN           NaN
# KBA05_VORB1                 NaN          NaN           NaN
# KBA05_VORB2                 NaN          NaN           NaN
# KBA05_ZUL1                  NaN          NaN           NaN
# KBA05_ZUL2                  NaN          NaN           NaN
# KBA05_ZUL3                  NaN          NaN           NaN
# KBA05_ZUL4                  NaN          NaN           NaN
# KBA05_HERSTTEMP        0.486576          NaN           NaN
# KBA05_MODTEMP               NaN          NaN      0.536424

# %% [markdown]
# From these examples we can see that the correlations occur frequently in variables that are aggregated into other variables. This is somewhat expected and can be verified by the variables' description on their documentation.
# To reduce the number of variables, those that aggregate information will be kept. If there are correlations within this subset of variables, another selection will be made.

# %%
kept = ['KBA05_AUTOQUOT',
        'KBA05_DIESEL',
        'KBA05_FRAU',
        'KBA05_GBZ',
        'KBA05_KRSAQUOT',
        'KBA05_KRSKLEIN',
        'KBA05_KRSOBER',
        'KBA05_KRSVAN',
        'KBA05_KRSZUL',
        'KBA05_MAXAH',
        'KBA05_MAXBJ',
        'KBA05_MAXHERST',
        'KBA05_MAXSEG',
        'KBA05_MAXVORB',
        'KBA05_MOTOR',
        'KBA05_MOTRAD',
        'KBA05_HERSTTEMP',
        'KBA05_MODTEMP']

# %%
v_frame.loc[kept, kept].style.background_gradient()
# Out:
# <style type="text/css">
# #T_fbfb7_row0_col0, #T_fbfb7_row1_col1, #T_fbfb7_row2_col2, #T_fbfb7_row3_col3, #T_fbfb7_row4_col4, #T_fbfb7_row5_col5, #T_fbfb7_row6_col6, #T_fbfb7_row7_col7, #T_fbfb7_row8_col8, #T_fbfb7_row9_col9, #T_fbfb7_row10_col10, #T_fbfb7_row11_col11, #T_fbfb7_row12_col12, #T_fbfb7_row13_col13, #T_fbfb7_row14_col14, #T_fbfb7_row15_col15, #T_fbfb7_row16_col16, #T_fbfb7_row17_col17 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fbfb7_row0_col1, #T_fbfb7_row1_col14, #T_fbfb7_row11_col14 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_fbfb7_row0_col2, #T_fbfb7_row9_col4 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_fbfb7_row0_col3 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_fbfb7_row0_col4, #T_fbfb7_row17_col16 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_fbfb7_row0_col5, #T_fbfb7_row2_col0, #T_fbfb7_row3_col9, #T_fbfb7_row5_col0, #T_fbfb7_row11_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_fbfb7_row0_col6, #T_fbfb7_row6_col0, #T_fbfb7_row11_col12, #T_fbfb7_row14_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_fbfb7_row0_col7, #T_fbfb7_row2_col3, #T_fbfb7_row4_col5, #T_fbfb7_row8_col1, #T_fbfb7_row9_col15, #T_fbfb7_row16_col12 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_fbfb7_row0_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_fbfb7_row0_col9 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_fbfb7_row0_col10, #T_fbfb7_row1_col2, #T_fbfb7_row2_col13, #T_fbfb7_row5_col10, #T_fbfb7_row7_col10, #T_fbfb7_row8_col2, #T_fbfb7_row8_col7, #T_fbfb7_row11_col0, #T_fbfb7_row14_col0, #T_fbfb7_row14_col2, #T_fbfb7_row14_col10, #T_fbfb7_row15_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T
{
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_fbfb7_row3_col4, #T_fbfb7_row4_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_fbfb7_row3_col15 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_fbfb7_row4_col0 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_fbfb7_row4_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_fbfb7_row4_col6, #T_fbfb7_row6_col17, #T_fbfb7_row17_col14 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_fbfb7_row4_col7, #T_fbfb7_row6_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_fbfb7_row4_col15 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_fbfb7_row5_col4, #T_fbfb7_row13_col3, #T_fbfb7_row17_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_fbfb7_row5_col12, #T_fbfb7_row16_col11 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_fbfb7_row5_col14 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_fbfb7_row5_col15, #T_fbfb7_row15_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_fbfb7_row5_col17 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_fb

# %%
to_drop = ['KBA05_GBZ','KBA05_AUTOQUOT','KBA05_MAXSEG','KBA05_HERSTTEMP']

# %% [markdown]
# Dropped:
#
# - 'KBA05_GBZ': The number of buildings is correlated to the main type of building. The type of building is more interesting to understand clusters
# - 'KBA05_AUTOQUOT': Correlated with KRSAUTOQUOT, that conveys the same information
# - 'KBA05_MAXSEG': Correlate with too many other features
# - 'KBA05_HERSTTEMP': Conveys similar information to MAXHERST, also strongly correlated to other variables

# %%
rr3_col_list = list(set(kept) - set(to_drop))

# %% [markdown]
# ## Community

# %% [markdown]
# Community actually contains continuous variables, therefore these will be kept, with exception of `RELAT_AB`, since it will convey similar information as `ARBEIT` when looking the variables' description

# %%
community_col_list = list(cramer_frame_list[2].columns.drop(['RELAT_AB']))

# %% [markdown]
# ## Household

# %%
cramer_frame_list[3].name
# Out:
# 'Household'

# %% [markdown]
# Looking into the columns in this category, we see that there might be some themes that we would like to avoid as date markers, considering the business we want to segment our customers for. E.g. the actuality of the transactions for telecommunications businessess (`D19_TELKO_DATUM`) might not be of interest for an mail-order organics company.
# We keep, therefore, only columns that might be pertinent for our case.

# %%
cramer_frame_list[3].columns
# Out:
# Index(['ALTER_HH', 'HH_EINKOMMEN_SCORE', 'D19_KONSUMTYP',
#        'D19_GESAMT_OFFLINE_DATUM', 'D19_GESAMT_ONLINE_DATUM',
#        'D19_GESAMT_DATUM', 'D19_BANKEN_OFFLINE_DATUM',
#        'D19_BANKEN_ONLINE_DATUM', 'D19_BANKEN_DATUM',
#        'D19_TELKO_OFFLINE_DATUM', 'D19_TELKO_ONLINE_DATUM', 'D19_TELKO_DATUM',
#        'D19_VERSAND_OFFLINE_DATUM', 'D19_VERSAND_ONLINE_DATUM',
#        'D19_VERSAND_DATUM', 'D19_VERSI_OFFLINE_DATUM',
#        'D19_VERSI_ONLINE_DATUM', 'D19_VERSI_DATUM',
#        'D19_GESAMT_ONLINE_QUOTE_12', 'D19_BANKEN_ONLINE_QUOTE_12',
#        'D19_VERSAND_ONLINE_QUOTE_12', 'W_KEIT_KIND_HH', 'WOHNDAUER_2008',
#        'D19_BANKEN_ANZ_12', 'D19_BANKEN_ANZ_24', 'D19_GESAMT_ANZ_12',
#        'D19_GESAMT_ANZ_24', 'D19_KONSUMTYP_MAX', 'D19_TELKO_ANZ_12',
#        'D19_TELKO_ANZ_24', 'D19_TELKO_ONLINE_QUOTE_12', 'D19_VERSAND_ANZ_12',
#        'D19_VERSAND_ANZ_24', 'D19_VERSI_ANZ_12', 'D19_VERSI_ANZ_24',
#        'D19_VERSI_ONLINE_QUOTE_12', 'ANZ_KINDER', 'ANZ_STATISTISCHE_HAUSHALTE',
#        'STRUKTURTYP'],
#       dtype='object')

# %%
household_cols_list = [#'ALTER_HH',
                        'HH_EINKOMMEN_SCORE',
                        'D19_KONSUMTYP',
                            'D19_GESAMT_OFFLINE_DATUM',
                            'D19_GESAMT_ONLINE_DATUM',
                            'D19_GESAMT_DATUM',
                            'D19_BANKEN_DATUM',
                            'D19_VERSAND_OFFLINE_DATUM',
                            'D19_VERSAND_ONLINE_DATUM',
                            'D19_VERSAND_DATUM',
                            'D19_GESAMT_ONLINE_QUOTE_12',
                            'D19_BANKEN_ONLINE_QUOTE_12',
                            'D19_VERSAND_ONLINE_QUOTE_12',
                            'W_KEIT_KIND_HH',
                            'WOHNDAUER_2008',
                            'D19_GESAMT_ANZ_12',
                            'D19_GESAMT_ANZ_24',
                            'D19_KONSUMTYP_MAX',
                            'D19_VERSAND_ANZ_12',
                            'D19_VERSAND_ANZ_24',
                            'ANZ_KINDER',
                            'ANZ_STATISTISCHE_HAUSHALTE',
                            'STRUKTURTYP']

# %%
cramer_frame_list[3].loc[household_cols_list, household_cols_list].style.background_gradient()
# Out:
# <style type="text/css">
# #T_1d796_row0_col0, #T_1d796_row1_col1, #T_1d796_row2_col2, #T_1d796_row3_col3, #T_1d796_row4_col4, #T_1d796_row5_col5, #T_1d796_row6_col6, #T_1d796_row7_col7, #T_1d796_row8_col8, #T_1d796_row9_col9, #T_1d796_row10_col10, #T_1d796_row11_col11, #T_1d796_row12_col12, #T_1d796_row13_col13, #T_1d796_row14_col14, #T_1d796_row15_col15, #T_1d796_row16_col16, #T_1d796_row17_col17, #T_1d796_row18_col18, #T_1d796_row19_col19, #T_1d796_row20_col20, #T_1d796_row21_col21 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1d796_row0_col1, #T_1d796_row0_col6, #T_1d796_row0_col18, #T_1d796_row1_col19, #T_1d796_row2_col12, #T_1d796_row3_col0, #T_1d796_row5_col8, #T_1d796_row6_col12, #T_1d796_row6_col20, #T_1d796_row7_col0, #T_1d796_row10_col17, #T_1d796_row17_col20, #T_1d796_row19_col15, #T_1d796_row19_col17, #T_1d796_row19_col18, #T_1d796_row20_col12, #T_1d796_row20_col17 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_1d796_row0_col2, #T_1d796_row0_col15, #T_1d796_row0_col16, #T_1d796_row2_col20, #T_1d796_row2_col21, #T_1d796_row3_col13, #T_1d796_row4_col13, #T_1d796_row4_col20, #T_1d796_row6_col5, #T_1d796_row7_col10, #T_1d796_row8_col20, #T_1d796_row9_col0, #T_1d796_row10_col4, #T_1d796_row10_col18, #T_1d796_row11_col0, #T_1d796_row14_col19, #T_1d796_row16_col21, #T_1d796_row17_col19, #T_1d796_row18_col19, #T_1d796_row20_col15, #T_1d796_row20_col16, #T_1d796_row20_col18 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T
{
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_1d796_row1_col13, #T_1d796_row4_col19, #T_1d796_row4_col21, #T_1d796_row9_col20, #T_1d796_row14_col21, #T_1d796_row19_col1, #T_1d796_row21_col13 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_1d796_row1_col15 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_1d796_row1_col16, #T_1d796_row8_col3, #T_1d796_row16_col1 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_1d796_row1_col17, #T_1d796_row8_col1, #T_1d796_row15_col9 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_1d796_row1_col18, #T_1d796_row4_col17, #T_1d796_row9_col14, #T_1d796_row17_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_1d796_row1_col20, #T_1d796_row2_col3, #T_1d796_row4_col12, #T_1d796_row6_col7, #T_1d796_row7_col6, #T_1d796_row8_col12, #T_1d796_row10_col3, #T_1d796_row12_col2, #T_1d796_row12_col5, #T_1d796_row12_col16 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_1d796_row2_col0, #T_1d796_row4_col0, #T_1d796_row12_col0, #T_1d796_row13_col20, #T_1d796_row15_col0, #T_1d796_row15_col20, #T_1d796_row18_col0, #T_1d796_row18_col10 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_1d796_row2_col1, #T_1d796_row14_col10 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_1d796_row2_col4, #T_1d796_row3_col5, #T_1d796_row5_col16, #T_1d796_row11_col16 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_1d796_row2_col6 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_1d796_row2_col7, #T_1d796_row3_col12, #T_1d796_row4_col10, #T_1d796_row5_col2, #T_1d796_row7_col5, #T_1d796_row7_col12, #T_1d796_row8_col5, #T_1d796_row12_col4, #T_1d796_row14_col12, #T_1d796_row16_col12, #T_1d796_row16_col20, #T_1d796_row18_col12 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_1d796_row2_col8 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_1d796_row2_col11, #T_1d796_row11_col2, #T_1d796_row11_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_1d796_row2_col15, #T_1d796_row2_col18, #T_1d796_row5_col1, #T_1d796_row5_col14, #T_1d796_row5_col15, #T_1d796_row15_col2, #T_1d796_row16_col10 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_1d796_row2_col17, #T_1d796_row6_col4, #T_1d796_row14_col2, #T_1d796_row16_col6 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_1d796_row2_col19, #T_1d796_row6_col19, #T_1d796_row19_col0, #T_1d796_row19_col8, #T_1d796_row19_col20, #T_1d796_row21_col12, #T_1d796_row21_col15 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1d796_row3_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_1d796_row3_col4, #T_1d796_row9_col11, #T_1d796_row11_col9 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_1d796_row3_col6, #T_1d796_row6_col3, #T_1d796_row9_col12, #T_1d796_row11_col12, #T_1d796_row12_col6, #T_1d796_row13_col0 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_1d796_row3_col7, #T_1d796_row7_col3 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_1d796_row3_col8 {
#   background-color

# %% [markdown]
# Online and offline data seem to be correlated. As well as 12 and 24 months data. The aggregate columns (identified by not having "online" or "offline" in the column names) will be kept for the first case, 12 months for the latter. 12 months is chosen because we want to segment the database into possible customers immediatly, therefore, more recent data is more interesting then longer time periods.

# %%
household_cols_list = [#'ALTER_HH',
                        'HH_EINKOMMEN_SCORE',
                        'D19_KONSUMTYP',
                        'D19_GESAMT_DATUM',
                        'D19_BANKEN_DATUM',
                        'D19_VERSAND_DATUM',
                        'D19_GESAMT_ONLINE_QUOTE_12',
                        'D19_BANKEN_ONLINE_QUOTE_12',
{
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5c612_row6_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_5c612_row6_col5, #T_5c612_row12_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_5c612_row6_col10 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_5c612_row6_col11 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_5c612_row7_col2, #T_5c612_row15_col14 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_5c612_row7_col10 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_5c612_row8_col12 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_5c612_row8_col13, #T_5c612_row10_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_5c612_row10_col5 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_5c612_row10_col6 {
#   backgrou

# %% [markdown]
# There are some other strong correlations, but considering that the data has a considerable amount of `NaN` values in itself, these redundancies are interesting to keep at some level to get homogeneus clusters.
# The only other correlation that will be handled is the `D19_KONSUMTYP` and the `D19_KONSUMTYP_MAX` since they convey the same information. The "max" column will be dropped

# %%
household_cols_list.remove('D19_KONSUMTYP_MAX')

# %% [markdown]
# ## RR4_ID

# %%
cramer_frame_list[5]
# Out:
#                  CAMEO_DEUG_2015  CAMEO_DEU_2015  KBA05_ALTER1  KBA05_ALTER2  \
# Attribute
# CAMEO_DEUG_2015         1.000000        1.000000      0.156121      0.080368
# CAMEO_DEU_2015          1.000000        1.000000      0.177400      0.146382
# KBA05_ALTER1            0.156121        0.177400      1.000000      0.069837
# KBA05_ALTER2            0.080368        0.146382      0.069837      1.000000
# KBA05_ALTER3            0.096975        0.115171      0.138553      0.270582
# KBA05_ALTER4            0.112977        0.178524      0.207337      0.276089
# KBA05_ANHANG            0.245989        0.266768      0.159244      0.096400
# KBA05_ANTG1             0.307384        0.321341      0.173502      0.095485
# KBA05_ANTG2             0.195404        0.210685      0.119041      0.071673
# KBA05_ANTG3             0.207195        0.220738      0.140370      0.076166
# KBA05_ANTG4             0.275275        0.288699      0.155803      0.093293
# CAMEO_INTL_2015         0.812627        1.000000      0.167059      0.136130
#
#                  KBA05_ALTER3  KBA05_ALTER4  KBA05_ANHANG  KBA05_ANTG1  \
# Attribute
# CAMEO_DEUG_2015      0.096975      0.112977      0.245989     0.307384
# CAMEO_DEU_2015       0.115171      0.178524      0.266768     0.321341
# KBA05_ALTER1         0.138553      0.207337      0.159244     0.173502
# KBA05_ALTER2         0.270582      0.276089      0.096400     0.095485
# KBA05_ALTER3         1.000000      0.156176      0.116907     0.118914
# KBA05_ALTER4         0.156176      1.000000      0.140397     0.134159
# KBA05_ANHANG         0.116907      0.140397      1.000000     0.318594
# KBA05_ANTG1          0.118914      0.134159      0.318594     1.000000
# KBA05_ANTG2          0.085626      0.097115      0.244595     0.367649
# KBA05_ANTG3          0.094501      0.098978      0.223573     0.412086
# KBA05_ANTG4          0.105175      0.158742      0.244924     0.398888
# CAMEO_INTL_2015      0.102966      0.164476      0.255598     0.315520
#
#                  KBA05_ANTG2  KBA05_ANTG3  KBA05_ANTG4  CAMEO_INTL_2015
# Attribute
# CAMEO_DEUG_2015     0.195404     0.207195     0.275275         0.812627
# CAMEO_DEU_2015      0.210685     0.220738     0.288699         1.000000
# KBA05_ALTER1        0.119041     0.140370     0.155803         0.167059
# KBA05_ALTER2        0.071673     0.076166     0.093293         0.136130
# KBA05_ALTER3        0.085626     0.094501     0.105175         0.102966
# KBA05_ALTER4        0.097115     0.098978     0.158742         0.164476
# KBA05_ANHANG        0.244595     0.223573     0.244924         0.255598
# KBA05_ANTG1         0.367649     0.412086     0.398888         0.315520
# KBA05_ANTG2         1.000000     0.344843     0.363847         0.203466
# KBA05_ANTG3         0.344843     1.000000     0.290603         0.214638
# KBA05_ANTG4         0.363847     0.290603     1.000000         0.276912
# CAMEO_INTL_2015     0.203466     0.214638     0.276912         1.000000

# %% [markdown]
# The KBA columns are misclassified (Should be RR3). They will be kept since they can convey useful information regarding the economic power of a respondent.

# %%
cramer_frame_list[5].loc[['CAMEO_DEUG_2015','CAMEO_DEU_2015','CAMEO_INTL_2015'],
                            ['CAMEO_DEUG_2015','CAMEO_DEU_2015','CAMEO_INTL_2015']]
# Out:
#                  CAMEO_DEUG_2015  CAMEO_DEU_2015  CAMEO_INTL_2015
# Attribute
# CAMEO_DEUG_2015         1.000000             1.0         0.812627
# CAMEO_DEU_2015          1.000000             1.0         1.000000
# CAMEO_INTL_2015         0.812627             1.0         1.000000

# %% [markdown]
# From their definition, it is natural that these columns are highly correlated. We will drop only the internation classification, just to have uniform definition of german demographics if they are useful to interpret clusters later on.

# %%
rr4_col_list = list(cramer_frame_list[5].columns.drop('CAMEO_INTL_2015'))

# %% [markdown]
# ## Person

# %% [markdown]
# The definition of columns in this category show how diverse each feature is. We will only look, therefore, to features that might correlate a lot to others and would not aggregate so much to our model

# %%
cramer_frame_list[6].name
# Out:
# 'Person'

# %%
((cramer_frame_list[6] > 0.3) & (cramer_frame_list[6] < 1)).sum().sort_values(ascending = False)
# Out:
# SEMIO_KULT               20
# SEMIO_ERL                20
# SEMIO_REL                19
# ANREDE_KZ                18
# SEMIO_TRADV              18
# SEMIO_KAEM               18
# SEMIO_RAT                18
# SEMIO_DOM                17
# ALTERSKATEGORIE_GROB     17
# SEMIO_KRIT               16
# SEMIO_VERT               15
# SEMIO_FAM                13
# SEMIO_SOZ                12
# CJT_TYP_1                12
# SEMIO_MAT                12
# AGER_TYP                 12
# HEALTH_TYP               12
# LP_LEBENSPHASE_FEIN      11
# SEMIO_PFLICHT            10
# SEMIO_LUST                9
# SHOPPER_TYP               8
# PRAEGENDE_JUGENDJAHRE     8
# LP_LEBENSPHASE_GROB       8
# CJT_TYP_5                 7
# FINANZ_MINIMALIST         7
# CJT_TYP_2                 7
# CJT_TYP_3                 7
# FINANZ_HAUSBAUER          7
# VERS_TYP                  7
# GREEN_AVANTGARDE          7
# CJT_TYP_6                 7
# CJT_TYP_4                 6
# ALTERSKATEGORIE_FEIN      6
# LP_STATUS_GROB            6
# LP_STATUS_FEIN            5
# ZABEOTYP                  3
# LP_FAMILIE_GROB           2
# LP_FAMILIE_FEIN           2
# CJT_KATALOGNUTZER         1
# FINANZ_ANLEGER            1
# FINANZTYP                 1
# FINANZ_SPARER             0
# CJT_GESAMTTYP             0
# FINANZ_VORSORGER          0
# FINANZ_UNAUFFAELLIGER     0
# GFK_URLAUBERTYP           0
# RETOURTYP_BK_S            0
# NATIONALITAET_KZ          0
# SOHO_KZ                   0
# dtype: int64

# %%
(cramer_frame_list[6][['SEMIO_KULT',
                    'SEMIO_ERL', 
                    'SEMIO_REL']] > 0.3).style.highlight_max(color = 'green')
# Out:
# <style type="text/css">
# #T_74a4c_row0_col0, #T_74a4c_row0_col1, #T_74a4c_row0_col2, #T_74a4c_row1_col0, #T_74a4c_row1_col1, #T_74a4c_row1_col2, #T_74a4c_row2_col0, #T_74a4c_row2_col1, #T_74a4c_row2_col2, #T_74a4c_row13_col0, #T_74a4c_row13_col1, #T_74a4c_row13_col2, #T_74a4c_row23_col0, #T_74a4c_row23_col1, #T_74a4c_row23_col2, #T_74a4c_row24_col0, #T_74a4c_row24_col1, #T_74a4c_row24_col2, #T_74a4c_row25_col0, #T_74a4c_row25_col1, #T_74a4c_row25_col2, #T_74a4c_row26_col0, #T_74a4c_row26_col1, #T_74a4c_row26_col2, #T_74a4c_row27_col0, #T_74a4c_row27_col1, #T_74a4c_row27_col2, #T_74a4c_row28_col0, #T_74a4c_row28_col1, #T_74a4c_row28_col2, #T_74a4c_row29_col0, #T_74a4c_row29_col1, #T_74a4c_row29_col2, #T_74a4c_row30_col0, #T_74a4c_row30_col1, #T_74a4c_row30_col2, #T_74a4c_row31_col0, #T_74a4c_row31_col1, #T_74a4c_row31_col2, #T_74a4c_row32_col0, #T_74a4c_row32_col1, #T_74a4c_row32_col2, #T_74a4c_row33_col0, #T_74a4c_row33_col1, #T_74a4c_row33_col2, #T_74a4c_row34_col0, #T_74a4c_row34_col1, #T_74a4c_row34_col2, #T_74a4c_row35_col0, #T_74a4c_row35_col1, #T_74a4c_row35_col2, #T_74a4c_row36_col0, #T_74a4c_row36_col1, #T_74a4c_row36_col2, #T_74a4c_row37_col0, #T_74a4c_row37_col1, #T_74a4c_row37_col2, #T_74a4c_row38_col0, #T_74a4c_row38_col1, #T_74a4c_row38_col2, #T_74a4c_row41_col0, #T_74a4c_row46_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_74a4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74a4c_level0_col0" class="col_heading level0 col0" >SEMIO_KULT</th>
#       <th id="T_74a4c_level0_col1" class="col_heading level0 col1" >SEMIO_ERL</th>
#       <th id="T_74a4c_level0_col2" class="col_heading level0 col2" >SEMIO_REL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Attribute</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74a4c_level0_row0" class="row_heading level0 row0" >AGER_TYP</th>
#       <td id="T_74a4c_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_74a4c_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_74a4c_row0_col2" class="data row0 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row1" class="row_heading level0 row1" >ALTERSKATEGORIE_GROB</th>
#       <td id="T_74a4c_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_74a4c_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_74a4c_row1_col2" class="data row1 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row2" class="row_heading level0 row2" >ANREDE_KZ</th>
#       <td id="T_74a4c_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_74a4c_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_74a4c_row2_col2" class="data row2 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row3" class="row_heading level0 row3" >CJT_GESAMTTYP</th>
#       <td id="T_74a4c_row3_col0" class="data row3 col0" >False</td>
#       <td id="T_74a4c_row3_col1" class="data row3 col1" >False</td>
#       <td id="T_74a4c_row3_col2" class="data row3 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row4" class="row_heading level0 row4" >FINANZ_MINIMALIST</th>
#       <td id="T_74a4c_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_74a4c_row4_col1" class="data row4 col1" >False</td>
#       <td id="T_74a4c_row4_col2" class="data row4 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row5" class="row_heading level0 row5" >FINANZ_SPARER</th>
#       <td id="T_74a4c_row5_col0" class="data row5 col0" >False</td>
#       <td id="T_74a4c_row5_col1" class="data row5 col1" >False</td>
#       <td id="T_74a4c_row5_col2" class="data row5 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row6" class="row_heading level0 row6" >FINANZ_VORSORGER</th>
#       <td id="T_74a4c_row6_col0" class="data row6 col0" >False</td>
#       <td id="T_74a4c_row6_col1" class="data row6 col1" >False</td>
#       <td id="T_74a4c_row6_col2" class="data row6 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row7" class="row_heading level0 row7" >FINANZ_ANLEGER</th>
#       <td id="T_74a4c_row7_col0" class="data row7 col0" >False</td>
#       <td id="T_74a4c_row7_col1" class="data row7 col1" >False</td>
#       <td id="T_74a4c_row7_col2" class="data row7 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row8" class="row_heading level0 row8" >FINANZ_UNAUFFAELLIGER</th>
#       <td id="T_74a4c_row8_col0" class="data row8 col0" >False</td>
#       <td id="T_74a4c_row8_col1" class="data row8 col1" >False</td>
#       <td id="T_74a4c_row8_col2" class="data row8 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row9" class="row_heading level0 row9" >FINANZ_HAUSBAUER</th>
#       <td id="T_74a4c_row9_col0" class="data row9 col0" >False</td>
#       <td id="T_74a4c_row9_col1" class="data row9 col1" >False</td>
#       <td id="T_74a4c_row9_col2" class="data row9 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row10" class="row_heading level0 row10" >FINANZTYP</th>
#       <td id="T_74a4c_row10_col0" class="data row10 col0" >False</td>
#       <td id="T_74a4c_row10_col1" class="data row10 col1" >False</td>
#       <td id="T_74a4c_row10_col2" class="data row10 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row11" class="row_heading level0 row11" >GFK_URLAUBERTYP</th>
#       <td id="T_74a4c_row11_col0" class="data row11 col0" >False</td>
#       <td id="T_74a4c_row11_col1" class="data row11 col1" >False</td>
#       <td id="T_74a4c_row11_col2" class="data row11 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row12" class="row_heading level0 row12" >GREEN_AVANTGARDE</th>
#       <td id="T_74a4c_row12_col0" class="data row12 col0" >False</td>
#       <td id="T_74a4c_row12_col1" class="data row12 col1" >False</td>
#       <td id="T_74a4c_row12_col2" class="data row12 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row13" class="row_heading level0 row13" >HEALTH_TYP</th>
#       <td id="T_74a4c_row13_col0" class="data row13 col0" >True</td>
#       <td id="T_74a4c_row13_col1" class="data row13 col1" >True</td>
#       <td id="T_74a4c_row13_col2" class="data row13 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row14" class="row_heading level0 row14" >LP_LEBENSPHASE_FEIN</th>
#       <td id="T_74a4c_row14_col0" class="data row14 col0" >False</td>
#       <td id="T_74a4c_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_74a4c_row14_col2" class="data row14 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row15" class="row_heading level0 row15" >LP_LEBENSPHASE_GROB</th>
#       <td id="T_74a4c_row15_col0" class="data row15 col0" >False</td>
#       <td id="T_74a4c_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_74a4c_row15_col2" class="data row15 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row16" class="row_heading level0 row16" >LP_FAMILIE_FEIN</th>
#       <td id="T_74a4c_row16_col0" class="data row16 col0" >False</td>
#       <td id="T_74a4c_row16_col1" class="data row16 col1" >False</td>
#       <td id="T_74a4c_row16_col2" class="data row16 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row17" class="row_heading level0 row17" >LP_FAMILIE_GROB</th>
#       <td id="T_74a4c_row17_col0" class="data row17 col0" >False</td>
#       <td id="T_74a4c_row17_col1" class="data row17 col1" >False</td>
#       <td id="T_74a4c_row17_col2" class="data row17 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row18" class="row_heading level0 row18" >LP_STATUS_FEIN</th>
#       <td id="T_74a4c_row18_col0" class="data row18 col0" >False</td>
#       <td id="T_74a4c_row18_col1" class="data row18 col1" >False</td>
#       <td id="T_74a4c_row18_col2" class="data row18 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_74a4c_level0_row19" class="row_heading level0 row19" >LP_STATUS_GROB</th>

# %% [markdown]
# We can see from the examples that the correlations show up mainly regarding gender and age, as well as correlations to other drivers.
# This means that mainly that the drivers (`SEMIO_`) are associated to certain demographics and we can expect some patterns to emerge from the drivers themselves.
# This is important information for a clustering exercise.
#
# Considering the general relevance of the variables to segment the demographics, we will keep all variables in this level

# %%
person_col_list = list(cramer_frame_list[6].columns.drop('AGER_TYP'))

# %% [markdown]
# ## PLZ8

# %% [markdown]
# From the definitions, we will drop initially columns related to very specific attributes of a car (Specific Manufacturer, for instance) and then check for possible correlation groups, like the `CCM, KMH and KW` columns, for example.
#
# This is because to segment customers demographically, it is more useful to know what kind of vehicle they drive and not necessairly the actual vehicle. We can then infer their spending patterns from this information. E.g. a more eco-friendly person might (i.e. a possible customer for organic produce) favor more low-power cars that don't emit so much CO2.

# %%
plz8_to_drop = ['KBA13_AUDI',
                'KBA13_BMW',
                'KBA13_FAB_ASIEN',
                'KBA13_FAB_SONSTIGE',
                'KBA13_FIAT',
                'KBA13_FORD',
                'KBA13_HERST_ASIEN',
                'KBA13_HERST_AUDI_VW',
                'KBA13_HERST_BMW_BENZ',
                'KBA13_HERST_EUROPA',
                'KBA13_HERST_FORD_OPEL',
                'KBA13_HERST_SONST',
                'KBA13_KRSHERST_AUDI_VW',
                'KBA13_KRSHERST_BMW_BENZ',
                'KBA13_KRSHERST_FORD_OPEL',
                'KBA13_MAZDA',
                'KBA13_MERCEDES',
                'KBA13_MOTOR',
                'KBA13_NISSAN',
                'KBA13_OPEL',
                'KBA13_PEUGEOT',
                'KBA13_RENAULT',
                'KBA13_TOYOTA',
                'KBA13_VW',
                'KBA13_SITZE_4',
                'KBA13_SITZE_5',
                'KBA13_SITZE_6']

# %%
plz8_kept = cramer_frame_list[7].columns.drop(plz8_to_drop)

# %%
len(plz8_kept)
# Out:
# 95

# %% [markdown]
# ### Horsepower correlations

# %%
hp_cols = ['KBA13_CCM_1000',
'KBA13_CCM_1200',
'KBA13_CCM_1400',
'KBA13_CCM_0_1400',
'KBA13_CCM_1500',
# 'KBA13_CCM_1400_2500', # Column NOT IN DATA
'KBA13_CCM_1600',
'KBA13_CCM_1800',
'KBA13_CCM_2000',
'KBA13_CCM_2500',
'KBA13_CCM_2501',
'KBA13_KMH_110',
'KBA13_KMH_140',
'KBA13_KMH_180',
'KBA13_KMH_0_140',
'KBA13_KMH_140_210',
'KBA13_KMH_211',
'KBA13_KMH_250',
'KBA13_KMH_251',
'KBA13_KW_30',
'KBA13_KW_40',
'KBA13_KW_50',
'KBA13_KW_60',
'KBA13_KW_0_60',
'KBA13_KW_70',
'KBA13_KW_61_120',
'KBA13_KW_80',
'KBA13_KW_90',
'KBA13_KW_110',
'KBA13_KW_120',
'KBA13_KW_121']

# %%
ccm_cols = ['KBA13_CCM_1000',
            'KBA13_CCM_1200',
            'KBA13_CCM_1400',
            'KBA13_CCM_0_1400',
            'KBA13_CCM_1500',
            # 'KBA13_CCM_1400_2500', # Column NOT IN DATA
            'KBA13_CCM_1600',
            'KBA13_CCM_1800',
            'KBA13_CCM_2000',
            'KBA13_CCM_2500',
            'KBA13_CCM_2501']

# %%
cramer_frame_list[7].loc[hp_cols, hp_cols].drop(ccm_cols).style.background_gradient()
# Out:
# <style type="text/css">
# #T_e681c_row0_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_e681c_row0_col1, #T_e681c_row2_col23, #T_e681c_row2_col26, #T_e681c_row4_col11, #T_e681c_row4_col17, #T_e681c_row11_col4, #T_e681c_row14_col26, #T_e681c_row16_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e681c_row0_col2, #T_e681c_row0_col27, #T_e681c_row1_col17, #T_e681c_row3_col17, #T_e681c_row5_col7, #T_e681c_row5_col25, #T_e681c_row6_col7, #T_e681c_row7_col13, #T_e681c_row9_col28, #T_e681c_row10_col19, #T_e681c_row12_col17, #T_e681c_row13_col24, #T_e681c_row14_col29, #T_e681c_row15_col22, #T_e681c_row16_col20, #T_e681c_row18_col20, #T_e681c_row19_col13, #T_e681c_row19_col18 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e681c_row0_col3 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_e681c_row0_col4 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_e681c_row0_col5, #T_e681c_row0_col22, #T_e681c_row0_col24, #T_e681c_row0_col29, #T_e681c_row1_col2, #T_e681c_row1_col27, #T_e681c_row3_col2, #T_e681c_row3_col27, #T_e681c_row3_col29, #T_e681c_row4_col19, #T_e681c_row5_col27, #T_e681c_row6_col25, #T_e681c_row6_col27, #T_e681c_row7_col11, #T_e681c_row7_col21, #T_e681c_row8_col12, #T_e681c_row8_col15, #T_e681c_row8_col16, #T_e681c_row9_col26, #T_e681c_row10_col26, #T_e681c_row13_col15, #T_e681c_row13_col16, #T_e681c_row13_col29, #T_e681c_row16_col5, #T_e681c_row16_col19, #T_e681c_row16_col21, #T_e681c_row17_col23, #T_e681c_row18_col21, #T_e681c_row18_col24, #T_e681c_row19_col10, #T_e681c_row19_col25 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T
{
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_e681c_row1_col18, #T_e681c_row17_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_e681c_row1_col19, #T_e681c_row19_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e681c_row1_col21, #T_e681c_row3_col15, #T_e681c_row3_col16, #T_e681c_row3_col21, #T_e681c_row3_col23, #T_e681c_row5_col26, #T_e681c_row6_col26, #T_e681c_row9_col25, #T_e681c_row10_col13, #T_e681c_row11_col25, #T_e681c_row13_col11, #T_e681c_row13_col17, #T_e681c_row13_col28, #T_e681c_row14_col1

# %% [markdown]
# Some correlations mainly between engine power in KW and horsepower emerge. Also it is good to notice columns that have range intersection, which results in higher correlations.
# Therefore, it might be nice to try out to keep only a single one of the criteria: CCM or KW generated. Evaluating their NaN can help us do this selection

# %%
census[hp_cols].isna().mean()
# Out:
# KBA13_CCM_1000       0.118714
# KBA13_CCM_1200       0.118714
# KBA13_CCM_1400       0.118714
# KBA13_CCM_0_1400     0.118714
# KBA13_CCM_1500       0.118714
# KBA13_CCM_1600       0.118714
# KBA13_CCM_1800       0.118714
# KBA13_CCM_2000       0.118714
# KBA13_CCM_2500       0.118714
# KBA13_CCM_2501       0.118714
# KBA13_KMH_110        0.118714
# KBA13_KMH_140        0.118714
# KBA13_KMH_180        0.118714
# KBA13_KMH_0_140      0.118714
# KBA13_KMH_140_210    0.118714
# KBA13_KMH_211        0.118714
# KBA13_KMH_250        0.118714
# KBA13_KMH_251        0.118714
# KBA13_KW_30          0.118714
# KBA13_KW_40          0.118714
# KBA13_KW_50          0.118714
# KBA13_KW_60          0.118714
# KBA13_KW_0_60        0.118714
# KBA13_KW_70          0.118714
# KBA13_KW_61_120      0.118714
# KBA13_KW_80          0.118714
# KBA13_KW_90          0.118714
# KBA13_KW_110         0.118714
# KBA13_KW_120         0.118714
# KBA13_KW_121         0.118714
# dtype: float64

# %% [markdown]
# They are similarly unpopulated. We can choose either one of them. CCM will be kept

# %%
kw_drop = ['KBA13_KW_30',
            'KBA13_KW_40',
            'KBA13_KW_50',
            'KBA13_KW_60',
            'KBA13_KW_0_60',
            'KBA13_KW_70',
            'KBA13_KW_61_120',
            'KBA13_KW_80',
            'KBA13_KW_90',
            'KBA13_KW_110',
            'KBA13_KW_120',
            'KBA13_KW_121',
            'KBA13_CCM_0_1400'] # Dropping CCM column because of intersection of ranges

# %%
plz8_kept = list(set(plz8_kept) - set(kw_drop))

# %%
len(plz8_kept)
# Out:
# 82

# %%
for col in plz8_kept:

    if 'ANTG' in col:

        print(col)
# Out:
# PLZ8_ANTG2
# PLZ8_ANTG3
# PLZ8_ANTG1
# KBA13_ANTG3
# PLZ8_ANTG4
# KBA13_ANTG2
# KBA13_ANTG1
# KBA13_ANTG4

# %% [markdown]
# Oddly enough, some columns have different prefixes but same name

# %%
plz_antg = ['PLZ8_ANTG1',
            'PLZ8_ANTG2',
            'PLZ8_ANTG3',
            'PLZ8_ANTG4']

kba13_antg = ['KBA13_ANTG1',
                'KBA13_ANTG2',
                'KBA13_ANTG3',
                'KBA13_ANTG4']

# %%
# Are the columns with the same name the same?
for pair in list(zip(plz_antg, kba13_antg)):


    print(
            ((census[pair[0]] == census[pair[1]]) == True).all()
        )
# Out:
# False
# False
# False
# False

# %% [markdown]
# Even though they have the same name, they are not totally the same. Since the `KBA13_ANTG` are not found in the documentation, the PLZ8 columns will be kept.

# %%
plz8_col_list = list(set(plz8_kept) - set(kba13_antg))

# %%
len(cramer_frame_list)
# Out:
# 10

# %% [markdown]
# ## Postcode

# %% [markdown]
# The definition of the variables suggests that they have some correlation.

# %%
cramer_frame_list[8].style.background_gradient()
# Out:
# <style type="text/css">
# #T_422f3_row0_col0, #T_422f3_row1_col1, #T_422f3_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_422f3_row0_col1, #T_422f3_row0_col2, #T_422f3_row2_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_422f3_row1_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_422f3_row1_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_422f3_row2_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_422f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_422f3_level0_col0" class="col_heading level0 col0" >BALLRAUM</th>
#       <th id="T_422f3_level0_col1" class="col_heading level0 col1" >EWDICHTE</th>
#       <th id="T_422f3_level0_col2" class="col_heading level0 col2" >INNENSTADT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Attribute</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_422f3_level0_row0" class="row_heading level0 row0" >BALLRAUM</th>
#       <td id="T_422f3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_422f3_row0_col1" class="data row0 col1" >0.340406</td>
#       <td id="T_422f3_row0_col2" class="data row0 col2" >0.337231</td>
#     </tr>
#     <tr>
#       <th id="T_422f3_level0_row1" class="row_heading level0 row1" >EWDICHTE</th>
#       <td id="T_422f3_row1_col0" class="data row1 col0" >0.340406</td>
#       <td id="T_422f3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_422f3_row1_col2" class="data row1 col2" >0.399588</td>
#     </tr>
#     <tr>
#       <th id="T_422f3_level0_row2" class="row_heading level0 row2" >INNENSTADT</th>
#       <td id="T_422f3_row2_col0" class="data row2 col0" >0.337231</td>
#       <td id="T_422f3_row2_col1" class="data row2 col1" >0.399588</td>
#       <td id="T_422f3_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# They do have some correlation, but since they represent relatively different characteriscs, they will not be dropped

# %%
postcode_col_list = list(cramer_frame_list[8].columns)

# %% [markdown]
# ## RR1_ID

# %%
cramer_frame_list[9].style.background_gradient()
# Out:
# <style type="text/css">
# #T_8b731_row0_col0, #T_8b731_row1_col1, #T_8b731_row2_col2, #T_8b731_row3_col3, #T_8b731_row4_col4, #T_8b731_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8b731_row0_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_8b731_row0_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_8b731_row0_col3, #T_8b731_row1_col2, #T_8b731_row1_col3, #T_8b731_row1_col5, #T_8b731_row3_col0, #T_8b731_row3_col1, #T_8b731_row3_col4, #T_8b731_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8b731_row0_col4, #T_8b731_row1_col0, #T_8b731_row2_col1, #T_8b731_row3_col2, #T_8b731_row4_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_8b731_row0_col5, #T_8b731_row2_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_8b731_row1_col4, #T_8b731_row4_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_8b731_row2_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_8b731_row2_col4, #T_8b731_row5_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_8b731_row2_col5 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_8b731_row3_col5, #T_8b731_row5_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_8b731_row4_col2, #T_8b731_row4_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_8b731_row5_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_8b731_row5_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_8b731_row5_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# </style>
# <table id="T_8b731">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b731_level0_col0" class="col_heading level0 col0" >GEBAEUDETYP_RASTER</th>
#       <th id="T_8b731_level0_col1" class="col_heading level0 col1" >KKK</th>
#       <th id="T_8b731_level0_col2" class="col_heading level0 col2" >MOBI_REGIO</th>
#       <th id="T_8b731_level0_col3" class="col_heading level0 col3" >ONLINE_AFFINITAET</th>
#       <th id="T_8b731_level0_col4" class="col_heading level0 col4" >REGIOTYP</th>
#       <th id="T_8b731_level0_col5" class="col_heading level0 col5" >MOBI_RASTER</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Attribute</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b731_level0_row0" class="row_heading level0 row0" >GEBAEUDETYP_RASTER</th>
#       <td id="T_8b731_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8b731_row0_col1" class="data row0 col1" >0.078496</td>
#       <td id="T_8b731_row0_col2" class="data row0 col2" >0.186512</td>
#       <td id="T_8b731_row0_col3" class="data row0 col3" >0.044300</td>
#       <td id="T_8b731_row0_col4" class="data row0 col4" >0.079294</td>
#       <td id="T_8b731_row0_col5" class="data row0 col5" >0.212790</td>
#     </tr>
#     <tr>
#       <th id="T_8b731_level0_row1" class="row_heading level0 row1" >KKK</th>
#       <td id="T_8b731_row1_col0" class="data row1 col0" >0.078496</td>
#       <td id="T_8b731_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8b731_row1_col2" class="data row1 col2" >0.081568</td>
#       <td id="T_8b731_row1_col3" class="data row1 col3" >0.047181</td>
#       <td id="T_8b731_row1_col4" class="data row1 col4" >0.603747</td>
#       <td id="T_8b731_row1_col5" class="data row1 col5" >0.076180</td>
#     </tr>
#     <tr>
#       <th id="T_8b731_level0_row2" class="row_heading level0 row2" >MOBI_REGIO</th>
#       <td id="T_8b731_row2_col0" class="data row2 col0" >0.186512</td>
#       <td id="T_8b731_row2_col1" class="data row2 col1" >0.081568</td>
#       <td id="T_8b731_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8b731_row2_col3" class="data row2 col3" >0.115377</td>
#       <td id="T_8b731_row2_col4" class="data row2 col4" >0.093296</td>
#       <td id="T_8b731_row2_col5" class="data row2 col5" >0.378735</td>
#     </tr>
#     <tr>
#       <th id="T_8b731_level0_row3" class="row_heading level0 row3" >ONLINE_AFFINITAET</th>
#       <td id="T_8b731_row3_col0" class="data row3 col0" >0.044300</td>
#       <td id="T_8b731_row3_col1" class="data row3 col1" >0.047181</td>
#       <td id="T_8b731_row3_col2" class="data row3 col2" >0.115377</td>
#       <td id="T_8b731_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8b731_row3_col4" class="data row3 col4" >0.043647</td>
#       <td id="T_8b731_row3_col5" class="data row3 col5" >0.102379</td>
#     </tr>
#     <tr>
#       <th id="T_8b731_level0_row4" class="row_heading level0 row4" >REGIOTYP</th>
#       <td id="T_8b731_row4_col0" class="data row4 col0" >0.079294</td>
#       <td id="T_8b731_row4_col1" class="data row4 col1" >0.603747</td>
#       <td id="T_8b731_row4_col2" class="data row4 col2" >0.093296</td>
#       <td id="T_8b731_row4_col3" class="data row4 col3" >0.043647</td>
#       <td id="T_8b731_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_8b731_row4_col5" class="data row4 col5" >0.092963</td>
#     </tr>
#     <tr>
#       <th id="T_8b731_level0_row5" class="row_heading level0 row5" >MOBI_RASTER</th>
#       <td id="T_8b731_row5_col0" class="data row5 col0" >0.212790</td>
#       <td id="T_8b731_row5_col1" class="data row5 col1" >0.076180</td>
#       <td id="T_8b731_row5_col2" class="data row5 col2" >0.378735</td>
#       <td id="T_8b731_row5_col3" class="data row5 col3" >0.102379</td>
#       <td id="T_8b731_row5_col4" class="data row5 col4" >0.092963</td>
#       <td id="T_8b731_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Neighbourhood typology and purchasing power are naturally correlated. It could be argued that they have a strong correlation given the 0 - 1 Scale from Cramer's V. Since they are so strongly correlated and we have geographical variables included in other levels (such as Community) the respondent Purchasing power (KKK) will be kept.
#
# Also, considering the present correlation from MOBI_RASTER and MOBI_REGIO and the fact that MOBI_RASTER was not found in the documentation, MOBI_RASTER will be dropped

# %%
rr1_cols = list(cramer_frame_list[9].columns.drop(['REGIOTYP','MOBI_RASTER']))

# %%
buildings_col_list
# Out:
# ['GEBAEUDETYP', 'KONSUMNAEHE', 'OST_WEST_KZ', 'WOHNLAGE']

# %% [markdown]
# # Generating first subset

# %%
# Some are dropped in the exclusion by NaN stage
kept_num_vars = list(np.intersect1d(census.columns, numeric_vars))

# %%
selected_features = ['LNR'] + \
                    kept_num_vars + \
                    grid_cols_list + \
                    buildings_col_list  + \
                    rr3_col_list  + \
                    community_col_list + \
                    household_cols_list + \
                    rr4_col_list + \
                    person_col_list + \
                    plz8_col_list + \
                    postcode_col_list + \
                    rr1_cols

# %%
print(len(selected_features), f'out of {census.shape[1]} features were selected to use in the segmentation')
# Out:
# 196 out of 335 features were selected to use in the segmentation

# %%
census[selected_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891221 entries, 0 to 891220
# Columns: 196 entries, LNR to ONLINE_AFFINITAET
# dtypes: float64(153), int64(41), object(2)
# memory usage: 1.3+ GB

# %%
df_customers.head()
# Out:
#       LNR  ANZ_HAUSHALTE_AKTIV  ANZ_HH_TITEL  ANZ_PERSONEN  ANZ_TITEL  \
# 0    9626                  1.0           0.0           2.0        0.0
# 2  143872                  1.0           0.0           1.0        0.0
# 3  143873                  0.0           0.0           0.0        0.0
# 4  143874                  7.0           0.0           4.0        0.0
# 5  143888                  1.0           0.0           2.0        0.0
#
#    KBA13_ANZAHL_PKW  MIN_GEBAEUDEJAHR  D19_BANKEN_DIREKT  D19_BANKEN_GROSS  \
# 0            1201.0            1992.0                0.0               0.0
# 2             433.0            1992.0                0.0               0.0
# 3             755.0            1992.0                0.0               0.0
# 4             513.0            1992.0                2.0               0.0
# 5            1167.0            1992.0                0.0               0.0
#
#    D19_BANKEN_LOKAL  ...  BALLRAUM  EWDICHTE  INNENSTADT  GEBAEUDETYP_RASTER  \
# 0               0.0  ...       3.0       2.0         4.0                 4.0
# 2               0.0  ...       7.0       4.0         1.0                 3.0
# 3               0.0  ...       7.0       1.0         7.0                 4.0
# 4               1.0  ...       3.0       4.0         4.0                 3.0
# 5               0.0  ...       7.0       5.0         8.0                 4.0
#
#    KKK  MOBI_REGIO  ONLINE_AFFINITAET  CUSTOMER_GROUP  ONLINE_PURCHASE  \
# 0  1.0         4.0                3.0     MULTI_BUYER                0
# 2  3.0         3.0                1.0     MULTI_BUYER                0
# 3  3.0         4.0                2.0     MULTI_BUYER                0
# 4  4.0         3.0                5.0     MULTI_BUYER                0
# 5  2.0         3.0                3.0     MULTI_BUYER                0
#
#        PRODUCT_GROUP
# 0  COSMETIC_AND_FOOD
# 2  COSMETIC_AND_FOOD
# 3           COSMETIC
# 4               FOOD
# 5  COSMETIC_AND_FOOD
#
# [5 rows x 175 columns]

# %%
df_customers[['CUSTOMER_GROUP','PRODUCT_GROUP']]
# Out:
#        CUSTOMER_GROUP      PRODUCT_GROUP
# 0         MULTI_BUYER  COSMETIC_AND_FOOD
# 2         MULTI_BUYER  COSMETIC_AND_FOOD
# 3         MULTI_BUYER           COSMETIC
# 4         MULTI_BUYER               FOOD
# 5         MULTI_BUYER  COSMETIC_AND_FOOD
# ...               ...                ...
# 191647    MULTI_BUYER  COSMETIC_AND_FOOD
# 191648   SINGLE_BUYER           COSMETIC
# 191649    MULTI_BUYER  COSMETIC_AND_FOOD
# 191650   SINGLE_BUYER               FOOD
# 191651    MULTI_BUYER  COSMETIC_AND_FOOD
#
# [140298 rows x 2 columns]

# %%
for col in ['CUSTOMER_GROUP','PRODUCT_GROUP']:

    display(df_customers[col].value_counts(dropna = False))
# Out:
# MULTI_BUYER     98547
# SINGLE_BUYER    41751
# Name: CUSTOMER_GROUP, dtype: int64
# COSMETIC_AND_FOOD    75446
# FOOD                 33779
# COSMETIC             31073
# Name: PRODUCT_GROUP, dtype: int64

# %%
X = df_customers.drop(columns = ['LNR','CUSTOMER_GROUP','PRODUCT_GROUP','ONLINE_PURCHASE'])

# %%
selected = []

for col in ['ONLINE_PURCHASE','PRODUCT_GROUP','CUSTOMER_GROUP']:

    print(f'Running for {col}')

    y = df_customers[col]

    selector = SelectKBest(mutual_info_classif, k = 10)

    selector.fit(X, y)

    selected.append(selector.get_feature_names_out())
# Out:
# Running for ONLINE_PURCHASE
# Running for PRODUCT_GROUP
# Running for CUSTOMER_GROUP

# %%
selected_features = list(np.append(selected[0],selected[1]))

selected_features = list(np.append(selected_features, selected[2]))

# %%
selected_features = list(set(selected_features))

# %%
len(selected_features)
# Out:
# 16

# %%
selected_features
# Out:
# ['FINANZ_VORSORGER',
#  'CJT_TYP_6',
#  'WOHNDAUER_2008',
#  'NATIONALITAET_KZ',
#  'VERS_TYP',
#  'CJT_TYP_3',
#  'OST_WEST_KZ',
#  'CJT_TYP_2',
#  'STRUKTURTYP',
#  'FINANZ_SPARER',
#  'CJT_TYP_5',
#  'D19_BANKEN_DATUM',
#  'CJT_KATALOGNUTZER',
#  'PRAEGENDE_JUGENDJAHRE',
#  'CJT_TYP_4',
#  'ANREDE_KZ']

# %% [markdown]
# From 100 possible variables, when we remove the intersections we are left with 73 candidates that are useful for segregating the categories in the customer data. We will try to cluster using these variables.
# We need only to pay attention to the numeric columns afterwards, since the mutual information criterion might not be so useful for classifying this type of data to help segregate categories.

# %%
with open('data/trusted/selected_features.pkl','wb') as file:

    pickle.dump(selected_features, file)
